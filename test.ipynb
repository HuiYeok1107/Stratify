# %%
def dirichlet_nonIID_domain_partition(t, client):
    print(t)
    proportions = t[1].copy()
    samples_per_client = (proportions * (20, 20, 20, 20, 20)).astype(int)

# %%
import numpy as np

dirProp = []
for i in range(4):    
    dirProp.append(np.random.dirichlet([0.5] * 5))

print(dirProp)
clients_traindf, clientsTrainLabelDataCount = dirichlet_nonIID_domain_partition(dirProp, 5)
clients_testdf, clientsTestDataCount = dirichlet_nonIID_domain_partition(dirProp, 5)
# Out:
# [array([0.03658901, 0.50074716, 0.38703367, 0.00695891, 0.06867126]), array([0.27436373, 0.33679172, 0.31612813, 0.07226241, 0.00045402]), array([2.13614383e-01, 4.04351815e-01, 3.53603767e-01, 2.83424433e-02,
#        8.75920163e-05]), array([0.17274319, 0.45667751, 0.01580005, 0.29033958, 0.06443967])]
# [array([0.03658901, 0.50074716, 0.38703367, 0.00695891, 0.06867126]), array([0.27436373, 0.33679172, 0.31612813, 0.07226241, 0.00045402]), array([2.13614383e-01, 4.04351815e-01, 3.53603767e-01, 2.83424433e-02,
#        8.75920163e-05]), array([0.17274319, 0.45667751, 0.01580005, 0.29033958, 0.06443967])]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       5     dirProp.append(np.random.dirichlet([0.5] * 5))
#       7 print(dirProp)
# ----> 8 clients_traindf, clientsTrainLabelDataCount = dirichlet_nonIID_domain_partition(dirProp, 5)
# ...
