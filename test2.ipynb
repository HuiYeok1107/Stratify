# %%
import testing
from testing import batch_size

# %%
testing.batch_size = 20
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 testing.batch_size = 20
#
# NameError: name 'testing' is not defined

# %%
testing.batch_size
# Out:
# 20
